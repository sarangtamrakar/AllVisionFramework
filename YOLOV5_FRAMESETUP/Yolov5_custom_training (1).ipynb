# %% [markdown]
# # YoloV5 Custom Training

# %%
# %cd /content/drive/MyDrive/YOLOV5_CUSTOM
# Out:
# /content/drive/MyDrive/YOLOV5_CUSTOM

# %% [markdown]
# ## Clone the Github Repo

# %%
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# !git reset --hard 68211f72c99915a15855f7b99bf5d93f5631330f
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 4650, done.
# remote: Total 4650 (delta 0), reused 0 (delta 0), pack-reused 4650
# Receiving objects: 100% (4650/4650), 7.47 MiB | 5.11 MiB/s, done.
# Resolving deltas: 100% (3176/3176), done.
# /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5
# HEAD is now at 68211f7 FROM nvcr.io/nvidia/pytorch:20.10-py3 (#1553)

# %% [markdown]
# ## Installing requirements

# %%
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 645kB 6.1MB/s
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16130MB, multi_processor_count=80)

# %% [markdown]
# ## Unzipping our Dataset

# %%
# %cd /content/drive/MyDrive/YOLOV5_CUSTOM/
# !unzip train.zip
# !unzip test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/wh_dresscode_0158.txt
#   inflating: train/labels/wh_dresscode_0159.txt
#   inflating: train/labels/wh_dresscode_0160.txt
#   inflating: train/labels/wh_dresscode_0161.txt
#   inflating: train/labels/wh_dresscode_0162.txt
#   inflating: train/labels/wh_dresscode_0163.txt
#   inflating: train/labels/wh_dresscode_0164.txt
#   inflating: train/labels/wh_dresscode_0165.txt
#   inflating: train/labels/wh_dresscode_0166.txt
#   inflating: train/labels/wh_dresscode_0167.txt
#   inflating: train/labels/wh_dresscode_0168.txt
#   inflating: train/labels/wh_dresscode_0169.txt
#   inflating: train/labels/wh_dresscode_0170.txt
#   inflating: train/labels/wh_dresscode_0171.txt
#   inflating: train/labels/wh_dresscode_0172.txt
#   inflating: train/labels/wh_dresscode_0173.txt
#   inflating: train/labels/wh_dresscode_0174.txt
#   inflating: train/labels/wh_dresscode_0175.txt
#   inflating: train/labels/wh_dresscode_0176.txt
#   inflating: train/labels/wh_dresscode_0177.txt
#   inflating: train/labels/wh_dresscode_0178.txt
#   inflating: train/labels/wh_dresscode_0179.txt
#   inflating: train/labels/wh_dresscode_0180.txt
#   inflating: train/labels/wh_dresscode_0181.txt
#   inflating: train/labels/wh_dresscode_0182.txt
#   inflating: train/labels/wh_dresscode_0183.txt
#   inflating: train/labels/wh_dresscode_0184.txt
#   inflating: train/labels/wh_dresscode_0185.txt
#   inflating: train/labels/wh_dresscode_0186.txt
#   inflating: train/labels/wh_dresscode_0055.txt
#   inflating: train/labels/wh_dresscode_0056.txt
#   inflating: train/labels/wh_dresscode_0187.txt
#   inflating: train/labels/wh_dresscode_0188.txt
#   inflating: train/labels/wh_dresscode_0189.txt
#   inflating: train/labels/wh_dresscode_0190.txt
#   inflating: train/labels/wh_dresscode_0191.txt
#   inflating: train/labels/wh_dresscode_0192.txt
#   inflating: train/labels/wh_dresscode_0193.txt
#   inflating: train/labels/wh_dresscode_0194.txt
#   inflating: train/labels/wh_dresscode_0195.txt
#   inflating: train/labels/wh_dresscode_0196.txt
#   inflating: test/labels/wh_dresscode_1992.txt
#   inflating: test/labels/wh_dresscode_1993.txt
#   inflating: test/labels/wh_dresscode_1994.txt
#   inflating: test/labels/wh_dresscode_1995.txt
#   inflating: test/labels/wh_dresscode_1996.txt
#   inflating: test/labels/wh_dresscode_1997.txt
#   inflating: test/labels/wh_dresscode_1998.txt
#   inflating: test/labels/wh_dresscode_1999.txt
#   inflating: test/labels/wh_dresscode_2000.txt

# %% [markdown]
# ## Checking the number of classes in our dataset

# %%
# %cat data.yaml
# Out:
# train: ../train/images
# val: ../test/images
#
# nc: 5
# names: ['hat','vest','goggles','glove','shoe']

# %% [markdown]
# ## # Defining number of classes

# %%
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %% [markdown]
# ## Model configuration for YoloV5

# %%
# %cat /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/models/yolov5s.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# ## Customize iPython writefile so we can write variables

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %% [markdown]
# ## Model Configuration for our Model

# %%
# %%writetemplate /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# ## Doing Changes in train.py for training

# %%
# %%writefile /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/utils/train.py
import argparse
import logging
import math
import os
import random
import time
from pathlib import Path
from warnings import warn

import numpy as np
import torch.distributed as dist
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.utils.data
import yaml
from torch.cuda import amp
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

import test  # import test.py to get mAP after each epoch
from models.yolo import Model
from utils.autoanchor import check_anchors
from utils.datasets import create_dataloader
from utils.general import labels_to_class_weights, increment_path, labels_to_image_weights, init_seeds, \
    fitness, strip_optimizer, get_latest_run, check_dataset, check_file, check_git_status, check_img_size, \
    print_mutation, set_logging
from utils.google_utils import attempt_download
from utils.loss import compute_loss
from utils.plots import plot_images, plot_labels, plot_results, plot_evolution
from utils.torch_utils import ModelEMA, select_device, intersect_dicts, torch_distributed_zero_first

logger = logging.getLogger(__name__)

try:
    import wandb
except ImportError:
    wandb = None
    logger.info("Install Weights & Biases for experiment logging via 'pip install wandb' (recommended)")


def train(hyp, opt, device, tb_writer=None, wandb=None):
    logger.info(f'Hyperparameters {hyp}')
    save_dir, epochs, batch_size, total_batch_size, weights, rank = \
        Path(opt.save_dir), opt.epochs, opt.batch_size, opt.total_batch_size, opt.weights, opt.global_rank

    # Directories
    wdir = save_dir / 'weights'
    wdir.mkdir(parents=True, exist_ok=True)  # make dir
    last = wdir / 'last.pt'
    best = wdir / 'best.pt'
    results_file = save_dir / 'results.txt'

    # Save run settings
    with open(save_dir / 'hyp.yaml', 'w') as f:
        yaml.dump(hyp, f, sort_keys=False)
    with open(save_dir / 'opt.yaml', 'w') as f:
        yaml.dump(vars(opt), f, sort_keys=False)

    # Configure
    plots = not opt.evolve  # create plots
    cuda = device.type != 'cpu'
    init_seeds(2 + rank)
    with open(opt.data) as f:
        data_dict = yaml.load(f, Loader=yaml.FullLoader)  # data dict
    with torch_distributed_zero_first(rank):
        check_dataset(data_dict)  # check
    train_path = data_dict['train']
    test_path = data_dict['val']
    nc, names = (1, ['item']) if opt.single_cls else (int(data_dict['nc']), data_dict['names'])  # number classes, names
    assert len(names) == nc, '%g names found for nc=%g dataset in %s' % (len(names), nc, opt.data)  # check

    # Model
    pretrained = weights.endswith('.pt')
    if pretrained:
        with torch_distributed_zero_first(rank):
            attempt_download(weights)  # download if not found locally
        ckpt = torch.load(weights, map_location=device)  # load checkpoint
        if hyp.get('anchors'):
            ckpt['model'].yaml['anchors'] = round(hyp['anchors'])  # force autoanchor
        model = Model(opt.cfg or ckpt['model'].yaml, ch=3, nc=nc).to(device)  # create
        exclude = ['anchor'] if opt.cfg or hyp.get('anchors') else []  # exclude keys
        state_dict = ckpt['model'].float().state_dict()  # to FP32
        state_dict = intersect_dicts(state_dict, model.state_dict(), exclude=exclude)  # intersect
        model.load_state_dict(state_dict, strict=False)  # load
        logger.info('Transferred %g/%g items from %s' % (len(state_dict), len(model.state_dict()), weights))  # report
    else:
        model = Model(opt.cfg, ch=3, nc=nc).to(device)  # create

    # Freeze
    freeze = []  # parameter names to freeze (full or partial)
    for k, v in model.named_parameters():
        v.requires_grad = True  # train all layers
        if any(x in k for x in freeze):
            print('freezing %s' % k)
            v.requires_grad = False

    # Optimizer
    nbs = 64  # nominal batch size
    accumulate = max(round(nbs / total_batch_size), 1)  # accumulate loss before optimizing
    hyp['weight_decay'] *= total_batch_size * accumulate / nbs  # scale weight_decay

    pg0, pg1, pg2 = [], [], []  # optimizer parameter groups
    for k, v in model.named_modules():
        if hasattr(v, 'bias') and isinstance(v.bias, nn.Parameter):
            pg2.append(v.bias)  # biases
        if isinstance(v, nn.BatchNorm2d):
            pg0.append(v.weight)  # no decay
        elif hasattr(v, 'weight') and isinstance(v.weight, nn.Parameter):
            pg1.append(v.weight)  # apply decay

    if opt.adam:
        optimizer = optim.Adam(pg0, lr=hyp['lr0'], betas=(hyp['momentum'], 0.999))  # adjust beta1 to momentum
    else:
        optimizer = optim.SGD(pg0, lr=hyp['lr0'], momentum=hyp['momentum'], nesterov=True)

    optimizer.add_param_group({'params': pg1, 'weight_decay': hyp['weight_decay']})  # add pg1 with weight_decay
    optimizer.add_param_group({'params': pg2})  # add pg2 (biases)
    logger.info('Optimizer groups: %g .bias, %g conv.weight, %g other' % (len(pg2), len(pg1), len(pg0)))
    del pg0, pg1, pg2

    # Scheduler https://arxiv.org/pdf/1812.01187.pdf
    # https://pytorch.org/docs/stable/_modules/torch/optim/lr_scheduler.html#OneCycleLR
    lf = lambda x: ((1 + math.cos(x * math.pi / epochs)) / 2) * (1 - hyp['lrf']) + hyp['lrf']  # cosine
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lf)
    # plot_lr_scheduler(optimizer, scheduler, epochs)

    # Logging
    if wandb and wandb.run is None:
        opt.hyp = hyp  # add hyperparameters
        wandb_run = wandb.init(config=opt, resume="allow",
                               project='YOLOv5' if opt.project == 'runs/train' else Path(opt.project).stem,
                               name=save_dir.stem,
                               id=ckpt.get('wandb_id') if 'ckpt' in locals() else None)

    # Resume
    start_epoch, best_fitness = 0, 0.0
    if pretrained:
        # Optimizer
        if ckpt['optimizer'] is not None:
            optimizer.load_state_dict(ckpt['optimizer'])
            best_fitness = ckpt['best_fitness']

        # Results
        if ckpt.get('training_results') is not None:
            with open(results_file, 'w') as file:
                file.write(ckpt['training_results'])  # write results.txt

        # Epochs
        start_epoch = ckpt['epoch'] + 1
        if opt.resume:
            assert start_epoch > 0, '%s training to %g epochs is finished, nothing to resume.' % (weights, epochs)
        if epochs < start_epoch:
            logger.info('%s has been trained for %g epochs. Fine-tuning for %g additional epochs.' %
                        (weights, ckpt['epoch'], epochs))
            epochs += ckpt['epoch']  # finetune additional epochs

        del ckpt, state_dict

    # Image sizes
    gs = int(max(model.stride))  # grid size (max stride)
    imgsz, imgsz_test = [check_img_size(x, gs) for x in opt.img_size]  # verify imgsz are gs-multiples

    # DP mode
    if cuda and rank == -1 and torch.cuda.device_count() > 1:
        model = torch.nn.DataParallel(model)

    # SyncBatchNorm
    if opt.sync_bn and cuda and rank != -1:
        model = torch.nn.SyncBatchNorm.convert_sync_batchnorm(model).to(device)
        logger.info('Using SyncBatchNorm()')

    # EMA
    ema = ModelEMA(model) if rank in [-1, 0] else None

    # DDP mode
    if cuda and rank != -1:
        model = DDP(model, device_ids=[opt.local_rank], output_device=opt.local_rank)

    # Trainloader
    dataloader, dataset = create_dataloader(train_path, imgsz, batch_size, gs, opt,
                                            hyp=hyp, augment=True, cache=opt.cache_images, rect=opt.rect, rank=rank,
                                            world_size=opt.world_size, workers=opt.workers)
    mlc = np.concatenate(dataset.labels, 0)[:, 0].max()  # max label class
    nb = len(dataloader)  # number of batches
    assert mlc < nc, 'Label class %g exceeds nc=%g in %s. Possible class labels are 0-%g' % (mlc, nc, opt.data, nc - 1)

    # Process 0
    if rank in [-1, 0]:
        ema.updates = start_epoch * nb // accumulate  # set EMA updates
        testloader = create_dataloader(test_path, imgsz_test, total_batch_size, gs, opt,
                                       hyp=hyp, cache=opt.cache_images and not opt.notest, rect=True,
                                       rank=-1, world_size=opt.world_size, workers=opt.workers)[0]  # testloader

        if not opt.resume:
            labels = np.concatenate(dataset.labels, 0)
            c = torch.tensor(labels[:, 0])  # classes
            # cf = torch.bincount(c.long(), minlength=nc) + 1.  # frequency
            # model._initialize_biases(cf.to(device))
            if plots:
                plot_labels(labels, save_dir=save_dir)
                if tb_writer:
                    tb_writer.add_histogram('classes', c, 0)
                if wandb:
                    wandb.log({"Labels": [wandb.Image(str(x), caption=x.name) for x in save_dir.glob('*labels*.png')]})

            # Anchors
            if not opt.noautoanchor:
                check_anchors(dataset, model=model, thr=hyp['anchor_t'], imgsz=imgsz)

    # Model parameters
    hyp['cls'] *= nc / 80.  # scale coco-tuned hyp['cls'] to current dataset
    model.nc = nc  # attach number of classes to model
    model.hyp = hyp  # attach hyperparameters to model
    model.gr = 1.0  # iou loss ratio (obj_loss = 1.0 or iou)
    model.class_weights = labels_to_class_weights(dataset.labels, nc).to(device)  # attach class weights
    model.names = names

    # Start training
    t0 = time.time()
    nw = max(round(hyp['warmup_epochs'] * nb), 1000)  # number of warmup iterations, max(3 epochs, 1k iterations)
    # nw = min(nw, (epochs - start_epoch) / 2 * nb)  # limit warmup to < 1/2 of training
    maps = np.zeros(nc)  # mAP per class
    results = (0, 0, 0, 0, 0, 0, 0)  # P, R, mAP@.5, mAP@.5-.95, val_loss(box, obj, cls)
    scheduler.last_epoch = start_epoch - 1  # do not move
    scaler = amp.GradScaler(enabled=cuda)
    logger.info('Image sizes %g train, %g test\n'
                'Using %g dataloader workers\nLogging results to %s\n'
                'Starting training for %g epochs...' % (imgsz, imgsz_test, dataloader.num_workers, save_dir, epochs))
    for epoch in range(start_epoch, epochs):  # epoch ------------------------------------------------------------------
        model.train()

        # Update image weights (optional)
        if opt.image_weights:
            # Generate indices
            if rank in [-1, 0]:
                cw = model.class_weights.cpu().numpy() * (1 - maps) ** 2  # class weights
                iw = labels_to_image_weights(dataset.labels, nc=nc, class_weights=cw)  # image weights
                dataset.indices = random.choices(range(dataset.n), weights=iw, k=dataset.n)  # rand weighted idx
            # Broadcast if DDP
            if rank != -1:
                indices = (torch.tensor(dataset.indices) if rank == 0 else torch.zeros(dataset.n)).int()
                dist.broadcast(indices, 0)
                if rank != 0:
                    dataset.indices = indices.cpu().numpy()

        # Update mosaic border
        # b = int(random.uniform(0.25 * imgsz, 0.75 * imgsz + gs) // gs * gs)
        # dataset.mosaic_border = [b - imgsz, -b]  # height, width borders

        mloss = torch.zeros(4, device=device)  # mean losses
        if rank != -1:
            dataloader.sampler.set_epoch(epoch)
        pbar = enumerate(dataloader)
        logger.info(('\n' + '%10s' * 8) % ('Epoch', 'gpu_mem', 'box', 'obj', 'cls', 'total', 'targets', 'img_size'))
        if rank in [-1, 0]:
            pbar = tqdm(pbar, total=nb)  # progress bar
        optimizer.zero_grad()
        for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
            ni = i + nb * epoch  # number integrated batches (since train start)
            imgs = imgs.to(device, non_blocking=True).float() / 255.0  # uint8 to float32, 0-255 to 0.0-1.0

            # Warmup
            if ni <= nw:
                xi = [0, nw]  # x interp
                # model.gr = np.interp(ni, xi, [0.0, 1.0])  # iou loss ratio (obj_loss = 1.0 or iou)
                accumulate = max(1, np.interp(ni, xi, [1, nbs / total_batch_size]).round())
                for j, x in enumerate(optimizer.param_groups):
                    # bias lr falls from 0.1 to lr0, all other lrs rise from 0.0 to lr0
                    x['lr'] = np.interp(ni, xi, [hyp['warmup_bias_lr'] if j == 2 else 0.0, x['initial_lr'] * lf(epoch)])
                    if 'momentum' in x:
                        x['momentum'] = np.interp(ni, xi, [hyp['warmup_momentum'], hyp['momentum']])

            # Multi-scale
            if opt.multi_scale:
                sz = random.randrange(imgsz * 0.5, imgsz * 1.5 + gs) // gs * gs  # size
                sf = sz / max(imgs.shape[2:])  # scale factor
                if sf != 1:
                    ns = [math.ceil(x * sf / gs) * gs for x in imgs.shape[2:]]  # new shape (stretched to gs-multiple)
                    imgs = F.interpolate(imgs, size=ns, mode='bilinear', align_corners=False)

            # Forward
            with amp.autocast(enabled=cuda):
                pred = model(imgs)  # forward
                loss, loss_items = compute_loss(pred, targets.to(device), model)  # loss scaled by batch_size
                if rank != -1:
                    loss *= opt.world_size  # gradient averaged between devices in DDP mode

            # Backward
            scaler.scale(loss).backward()

            # Optimize
            if ni % accumulate == 0:
                scaler.step(optimizer)  # optimizer.step
                scaler.update()
                optimizer.zero_grad()
                if ema:
                    ema.update(model)

            # Print
            if rank in [-1, 0]:
                mloss = (mloss * i + loss_items) / (i + 1)  # update mean losses
                mem = '%.3gG' % (torch.cuda.memory_reserved() / 1E9 if torch.cuda.is_available() else 0)  # (GB)
                s = ('%10s' * 2 + '%10.4g' * 6) % (
                    '%g/%g' % (epoch, epochs - 1), mem, *mloss, targets.shape[0], imgs.shape[-1])
                pbar.set_description(s)

                # Plot
                if plots and ni < 3:
                    f = save_dir / f'train_batch{ni}.jpg'  # filename
                    plot_images(images=imgs, targets=targets, paths=paths, fname=f)
                    # if tb_writer:
                    #     tb_writer.add_image(f, result, dataformats='HWC', global_step=epoch)
                    #     tb_writer.add_graph(model, imgs)  # add model to tensorboard
                elif plots and ni == 3 and wandb:
                    wandb.log({"Mosaics": [wandb.Image(str(x), caption=x.name) for x in save_dir.glob('train*.jpg')]})

            # end batch ------------------------------------------------------------------------------------------------
        # end epoch ----------------------------------------------------------------------------------------------------

        # Scheduler
        lr = [x['lr'] for x in optimizer.param_groups]  # for tensorboard
        scheduler.step()

        # DDP process 0 or single-GPU
        if rank in [-1, 0]:
            # mAP
            if ema:
                ema.update_attr(model, include=['yaml', 'nc', 'hyp', 'gr', 'names', 'stride'])
            final_epoch = epoch + 1 == epochs
            if not opt.notest or final_epoch:  # Calculate mAP
                results, maps, times = test.test(opt.data,
                                                 batch_size=total_batch_size,
                                                 imgsz=imgsz_test,
                                                 model=ema.ema,
                                                 single_cls=opt.single_cls,
                                                 dataloader=testloader,
                                                 save_dir=save_dir,
                                                 plots=plots and final_epoch,
                                                 log_imgs=opt.log_imgs if wandb else 0)

            # Write
            with open(results_file, 'a') as f:
                f.write(s + '%10.4g' * 7 % results + '\n')  # P, R, mAP@.5, mAP@.5-.95, val_loss(box, obj, cls)
            if len(opt.name) and opt.bucket:
                os.system('gsutil cp %s gs://%s/results/results%s.txt' % (results_file, opt.bucket, opt.name))

            # Log
            tags = ['train/box_loss', 'train/obj_loss', 'train/cls_loss',  # train loss
                    'metrics/precision', 'metrics/recall', 'metrics/mAP_0.5', 'metrics/mAP_0.5:0.95',
                    'val/box_loss', 'val/obj_loss', 'val/cls_loss',  # val loss
                    'x/lr0', 'x/lr1', 'x/lr2']  # params
            for x, tag in zip(list(mloss[:-1]) + list(results) + lr, tags):
                if tb_writer:
                    tb_writer.add_scalar(tag, x, epoch)  # tensorboard
                if wandb:
                    wandb.log({tag: x})  # W&B

            # Update best mAP
            fi = fitness(np.array(results).reshape(1, -1))  # weighted combination of [P, R, mAP@.5, mAP@.5-.95]
            if fi > best_fitness:
                best_fitness = fi

            # Save model
            save = (not opt.nosave) or (final_epoch and not opt.evolve)
            if save:
                with open(results_file, 'r') as f:  # create checkpoint
                    ckpt = {'epoch': epoch,
                            'best_fitness': best_fitness,
                            'training_results': f.read(),
                            'model': ema.ema,
                            'optimizer': None if final_epoch else optimizer.state_dict(),
                            'wandb_id': wandb_run.id if wandb else None}

                # Save last, best and delete
                torch.save(ckpt, last)
                if best_fitness == fi:
                    torch.save(ckpt, best)
                del ckpt
        # end epoch ----------------------------------------------------------------------------------------------------
    # end training

    if rank in [-1, 0]:
        # Strip optimizers
        n = opt.name if opt.name.isnumeric() else ''
        fresults, flast, fbest = save_dir / f'results{n}.txt', wdir / f'last{n}.pt', wdir / f'best{n}.pt'
        for f1, f2 in zip([wdir / 'last.pt', wdir / 'best.pt', results_file], [flast, fbest, fresults]):
            if f1.exists():
                os.rename(f1, f2)  # rename
                if str(f2).endswith('.pt'):  # is *.pt
                    strip_optimizer(f2)  # strip optimizer
                    os.system('gsutil cp %s gs://%s/weights' % (f2, opt.bucket)) if opt.bucket else None  # upload
        # Finish
        if plots:
            plot_results(save_dir=save_dir)  # save as results.png
            if wandb:
                files = ['results.png', 'precision_recall_curve.png', 'confusion_matrix.png']
                wandb.log({"Results": [wandb.Image(str(save_dir / f), caption=f) for f in files
                                       if (save_dir / f).exists()]})
        logger.info('%g epochs completed in %.3f hours.\n' % (epoch - start_epoch + 1, (time.time() - t0) / 3600))
    else:
        dist.destroy_process_group()

    wandb.run.finish() if wandb and wandb.run else None
    torch.cuda.empty_cache()
    return results


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--weights', type=str, default='yolov5s.pt', help='initial weights path')
    parser.add_argument('--cfg', type=str, default='', help='model.yaml path')
    parser.add_argument('--data', type=str, default='data/coco128.yaml', help='data.yaml path')
    parser.add_argument('--hyp', type=str, default='data/hyp.scratch.yaml', help='hyperparameters path')
    parser.add_argument('--epochs', type=int, default=300)
    parser.add_argument('--batch-size', type=int, default=16, help='total batch size for all GPUs')
    parser.add_argument('--img-size', nargs='+', type=int, default=[640, 640], help='[train, test] image sizes')
    parser.add_argument('--rect', action='store_true', help='rectangular training')
    parser.add_argument('--resume', nargs='?', const=True, default=False, help='resume most recent training')
    parser.add_argument('--nosave', action='store_true', help='only save final checkpoint')
    parser.add_argument('--notest', action='store_true', help='only test final epoch')
    parser.add_argument('--noautoanchor', action='store_true', help='disable autoanchor check')
    parser.add_argument('--evolve', action='store_true', help='evolve hyperparameters')
    parser.add_argument('--bucket', type=str, default='', help='gsutil bucket')
    parser.add_argument('--cache-images', action='store_true', help='cache images for faster training')
    parser.add_argument('--image-weights', action='store_true', help='use weighted image selection for training')
    parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
    parser.add_argument('--multi-scale', action='store_true', help='vary img-size +/- 50%%')
    parser.add_argument('--single-cls', action='store_true', help='train as single-class dataset')
    parser.add_argument('--adam', action='store_true', help='use torch.optim.Adam() optimizer')
    parser.add_argument('--sync-bn', action='store_true', help='use SyncBatchNorm, only available in DDP mode')
    parser.add_argument('--local_rank', type=int, default=-1, help='DDP parameter, do not modify')
    parser.add_argument('--log-imgs', type=int, default=16, help='number of images for W&B logging, max 100')
    parser.add_argument('--workers', type=int, default=8, help='maximum number of dataloader workers')
    parser.add_argument('--project', default='runs/train', help='save to project/name')
    parser.add_argument('--name', default='exp', help='save to project/name')
    parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
    opt = parser.parse_args()

    # Set DDP variables
    opt.total_batch_size = opt.batch_size
    opt.world_size = int(os.environ['WORLD_SIZE']) if 'WORLD_SIZE' in os.environ else 1
    opt.global_rank = int(os.environ['RANK']) if 'RANK' in os.environ else -1
    set_logging(opt.global_rank)
    if opt.global_rank in [-1, 0]:
        check_git_status()

    # Resume
    if opt.resume:  # resume an interrupted run
        ckpt = opt.resume if isinstance(opt.resume, str) else get_latest_run()  # specified or most recent path
        assert os.path.isfile(ckpt), 'ERROR: --resume checkpoint does not exist'
        with open(Path(ckpt).parent.parent / 'opt.yaml') as f:
            opt = argparse.Namespace(**yaml.load(f, Loader=yaml.FullLoader))  # replace
        opt.cfg, opt.weights, opt.resume = '', ckpt, True
        logger.info('Resuming training from %s' % ckpt)
    else:
        # opt.hyp = opt.hyp or ('hyp.finetune.yaml' if opt.weights else 'hyp.scratch.yaml')
        opt.data, opt.cfg, opt.hyp = check_file(opt.data), check_file(opt.cfg), check_file(opt.hyp)  # check files
        assert len(opt.cfg) or len(opt.weights), 'either --cfg or --weights must be specified'
        opt.img_size.extend([opt.img_size[-1]] * (2 - len(opt.img_size)))  # extend to 2 sizes (train, test)
        opt.name = 'evolve' if opt.evolve else opt.name
        opt.save_dir = increment_path(Path(opt.project) / opt.name, exist_ok=opt.exist_ok | opt.evolve)  # increment run

    # DDP mode
    device = select_device(opt.device, batch_size=opt.batch_size)
    if opt.local_rank != -1:
        assert torch.cuda.device_count() > opt.local_rank
        torch.cuda.set_device(opt.local_rank)
        device = torch.device('cuda', opt.local_rank)
        dist.init_process_group(backend='nccl', init_method='env://')  # distributed backend
        assert opt.batch_size % opt.world_size == 0, '--batch-size must be multiple of CUDA device count'
        opt.batch_size = opt.total_batch_size // opt.world_size

    # Hyperparameters
    with open(opt.hyp) as f:
        hyp = yaml.load(f, Loader=yaml.FullLoader)  # load hyps
        if 'box' not in hyp:
            warn('Compatibility: %s missing "box" which was renamed from "giou" in %s' %
                 (opt.hyp, 'https://github.com/ultralytics/yolov5/pull/1120'))
            hyp['box'] = hyp.pop('giou')

    # Train
    logger.info(opt)
    if not opt.evolve:
        tb_writer = None  # init loggers
        if opt.global_rank in [-1, 0]:
            logger.info(f'Start Tensorboard with "tensorboard --logdir {opt.project}", view at http://localhost:6006/')
            tb_writer = SummaryWriter(opt.save_dir)  # Tensorboard
        train(hyp, opt, device, tb_writer, wandb)

    # Evolve hyperparameters (optional)
    else:
        # Hyperparameter evolution metadata (mutation scale 0-1, lower_limit, upper_limit)
        meta = {'lr0': (1, 1e-5, 1e-1),  # initial learning rate (SGD=1E-2, Adam=1E-3)
                'lrf': (1, 0.01, 1.0),  # final OneCycleLR learning rate (lr0 * lrf)
                'momentum': (0.3, 0.6, 0.98),  # SGD momentum/Adam beta1
                'weight_decay': (1, 0.0, 0.001),  # optimizer weight decay
                'warmup_epochs': (1, 0.0, 5.0),  # warmup epochs (fractions ok)
                'warmup_momentum': (1, 0.0, 0.95),  # warmup initial momentum
                'warmup_bias_lr': (1, 0.0, 0.2),  # warmup initial bias lr
                'box': (1, 0.02, 0.2),  # box loss gain
                'cls': (1, 0.2, 4.0),  # cls loss gain
                'cls_pw': (1, 0.5, 2.0),  # cls BCELoss positive_weight
                'obj': (1, 0.2, 4.0),  # obj loss gain (scale with pixels)
                'obj_pw': (1, 0.5, 2.0),  # obj BCELoss positive_weight
                'iou_t': (0, 0.1, 0.7),  # IoU training threshold
                'anchor_t': (1, 2.0, 8.0),  # anchor-multiple threshold
                'anchors': (2, 2.0, 10.0),  # anchors per output grid (0 to ignore)
                'fl_gamma': (0, 0.0, 2.0),  # focal loss gamma (efficientDet default gamma=1.5)
                'hsv_h': (1, 0.0, 0.1),  # image HSV-Hue augmentation (fraction)
                'hsv_s': (1, 0.0, 0.9),  # image HSV-Saturation augmentation (fraction)
                'hsv_v': (1, 0.0, 0.9),  # image HSV-Value augmentation (fraction)
                'degrees': (1, 0.0, 45.0),  # image rotation (+/- deg)
                'translate': (1, 0.0, 0.9),  # image translation (+/- fraction)
                'scale': (1, 0.0, 0.9),  # image scale (+/- gain)
                'shear': (1, 0.0, 10.0),  # image shear (+/- deg)
                'perspective': (0, 0.0, 0.001),  # image perspective (+/- fraction), range 0-0.001
                'flipud': (1, 0.0, 1.0),  # image flip up-down (probability)
                'fliplr': (0, 0.0, 1.0),  # image flip left-right (probability)
                'mosaic': (1, 0.0, 1.0),  # image mixup (probability)
                'mixup': (1, 0.0, 1.0)}  # image mixup (probability)

        assert opt.local_rank == -1, 'DDP mode not implemented for --evolve'
        opt.notest, opt.nosave = True, True  # only test/save final epoch
        # ei = [isinstance(x, (int, float)) for x in hyp.values()]  # evolvable indices
        yaml_file = Path(opt.save_dir) / 'hyp_evolved.yaml'  # save best result here
        if opt.bucket:
            os.system('gsutil cp gs://%s/evolve.txt .' % opt.bucket)  # download evolve.txt if exists

        for _ in range(300):  # generations to evolve
            if Path('evolve.txt').exists():  # if evolve.txt exists: select best hyps and mutate
                # Select parent(s)
                parent = 'single'  # parent selection method: 'single' or 'weighted'
                x = np.loadtxt('evolve.txt', ndmin=2)
                n = min(5, len(x))  # number of previous results to consider
                x = x[np.argsort(-fitness(x))][:n]  # top n mutations
                w = fitness(x) - fitness(x).min()  # weights
                if parent == 'single' or len(x) == 1:
                    # x = x[random.randint(0, n - 1)]  # random selection
                    x = x[random.choices(range(n), weights=w)[0]]  # weighted selection
                elif parent == 'weighted':
                    x = (x * w.reshape(n, 1)).sum(0) / w.sum()  # weighted combination

                # Mutate
                mp, s = 0.8, 0.2  # mutation probability, sigma
                npr = np.random
                npr.seed(int(time.time()))
                g = np.array([x[0] for x in meta.values()])  # gains 0-1
                ng = len(meta)
                v = np.ones(ng)
                while all(v == 1):  # mutate until a change occurs (prevent duplicates)
                    v = (g * (npr.random(ng) < mp) * npr.randn(ng) * npr.random() * s + 1).clip(0.3, 3.0)
                for i, k in enumerate(hyp.keys()):  # plt.hist(v.ravel(), 300)
                    hyp[k] = float(x[i + 7] * v[i])  # mutate

            # Constrain to limits
            for k, v in meta.items():
                hyp[k] = max(hyp[k], v[1])  # lower limit
                hyp[k] = min(hyp[k], v[2])  # upper limit
                hyp[k] = round(hyp[k], 5)  # significant digits

            # Train mutation
            results = train(hyp.copy(), opt, device, wandb=wandb)

            # Write mutation results
            print_mutation(hyp.copy(), results, yaml_file, opt.bucket)

        # Plot results
        plot_evolution(yaml_file)
        print(f'Hyperparameter evolution complete. Best results saved as: {yaml_file}\n'
              f'Command to train a new model with these hyperparameters: $ python train.py --hyp {yaml_file}')
# Out:
# Writing /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/utils/train.py

# %% [markdown]
# ## Let's Start Training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5
# !python train.py --img 416 --batch 16 --epochs 100 --data '/content/drive/MyDrive/YOLOV5_CUSTOM/data.yaml' --cfg /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5
# Using torch 1.7.0+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16130MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='/content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/models/custom_yolov5s.yaml', data='/content/drive/MyDrive/YOLOV5_CUSTOM/data.yaml', device='', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], local_rank=-1, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolov5s_results2', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2021-02-06 11:32:57.894637: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Hyperparameters {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     26970  models.yolo.Detect                      [5, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7265882 parameters, 7265882 gradients
#
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# Scanning '../train/labels.cache' for images and labels... 2992 found, 8 missing, 1 empty, 0 corrupted: 100% 3000/3000 [00:00<00:00, 31457280.00it/s]
# Caching images (1.2GB): 100% 3000/3000 [00:14<00:00, 209.02it/s]
# Scanning '../test/labels' for images and labels... 1051 found, 8 missing, 0 empty, 0 corrupted: 100% 1059/1059 [00:02<00:00, 468.25it/s]
# New cache created: ../test/labels.cache
# Scanning '../test/labels.cache' for images and labels... 1051 found, 8 missing, 0 empty, 0 corrupted: 100% 1059/1059 [00:00<00:00, 9390629.89it/s]
# Caching images (0.4GB): 100% 1059/1059 [00:06<00:00, 173.05it/s]
# NumExpr defaulting to 4 threads.
#
# Analyzing anchors... anchors/target = 5.02, Best Possible Recall (BPR) = 0.9994
# Image sizes 416 train, 416 test
# Using 4 dataloader workers
# Logging results to runs/train/yolov5s_results2
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       0/99     1.85G    0.1016    0.1058   0.04547    0.2529        48       416: 100% 188/188 [00:23<00:00,  7.88it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:08<00:00,  7.85it/s]
#                  all    1.06e+03     3.6e+03     0.00323    0.000922     0.00149    0.000326
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       1/99     1.86G    0.0976    0.1103   0.04037    0.2482        41       416: 100% 188/188 [00:20<00:00,  9.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:11<00:00,  5.99it/s]
#                  all    1.06e+03     3.6e+03     0.00286     0.00613     0.00486    0.000917
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       2/99     1.86G    0.0927    0.1072   0.03624    0.2362        37       416: 100% 188/188 [00:19<00:00,  9.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:11<00:00,  5.76it/s]
#                  all    1.06e+03     3.6e+03      0.0208       0.112      0.0191     0.00365
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       3/99     1.86G   0.08481    0.1073   0.02804    0.2201        46       416: 100% 188/188 [00:18<00:00, 10.00it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:17<00:00,  3.85it/s]
#                  all    1.06e+03     3.6e+03      0.0211       0.236      0.0388     0.00914
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       4/99     1.86G   0.08034    0.1004   0.02232    0.2031        64       416: 100% 188/188 [00:18<00:00, 10.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:08<00:00,  8.17it/s]
#                  all    1.06e+03     3.6e+03       0.053       0.182      0.0891      0.0278
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       5/99     1.86G   0.07466   0.09793   0.01922    0.1918        32       416: 100% 188/188 [00:18<00:00, 10.17it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:08<00:00,  8.15it/s]
#                  all    1.06e+03     3.6e+03       0.133       0.307       0.205      0.0666
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       6/99     1.86G   0.06915   0.09624    0.0157    0.1811        42       416: 100% 188/188 [00:18<00:00, 10.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:08<00:00,  7.74it/s]
#                  all    1.06e+03     3.6e+03       0.102        0.32       0.224      0.0788
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       7/99     1.86G   0.06489   0.09188   0.01411    0.1709        37       416: 100% 188/188 [00:18<00:00, 10.20it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  8.44it/s]
#                  all    1.06e+03     3.6e+03       0.229       0.416       0.324       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       8/99     1.86G   0.06227   0.09213   0.01231    0.1667        38       416: 100% 188/188 [00:18<00:00, 10.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:08<00:00,  8.28it/s]
#                  all    1.06e+03     3.6e+03       0.223       0.463       0.343       0.139
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#       9/99     1.86G   0.06078   0.08898   0.01163    0.1614        51       416: 100% 188/188 [00:18<00:00, 10.34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00
34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  8.66it/s]
#                  all    1.06e+03     3.6e+03        0.49       0.746       0.671       0.331
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      93/99     1.86G   0.03634   0.06176  0.003035    0.1011        78       416: 100% 188/188 [00:18<00:00, 10.15it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  9.09it/s]
#                  all    1.06e+03     3.6e+03       0.492       0.749       0.672       0.327
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      94/99     1.86G   0.03597   0.06099  0.002797   0.09975        61       416: 100% 188/188 [00:18<00:00, 10.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  9.16it/s]
#                  all    1.06e+03     3.6e+03       0.481       0.753       0.671       0.323
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      95/99     1.86G   0.03629   0.06211  0.003008    0.1014        39       416: 100% 188/188 [00:18<00:00,  9.94it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  9.29it/s]
#                  all    1.06e+03     3.6e+03       0.482       0.749       0.669       0.326
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      96/99     1.86G   0.03608   0.06102  0.002721   0.09982        47       416: 100% 188/188 [00:18<00:00, 10.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  9.15it/s]
#                  all    1.06e+03     3.6e+03       0.488       0.754        0.67       0.325
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      97/99     1.86G   0.03637   0.06089  0.002736       0.1        30       416: 100% 188/188 [00:18<00:00, 10.20it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  9.14it/s]
#                  all    1.06e+03     3.6e+03       0.497       0.751       0.678       0.323
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      98/99     1.86G   0.03575   0.06091  0.002907   0.09957        61       416: 100% 188/188 [00:18<00:00, 10.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:07<00:00,  8.76it/s]
#                  all    1.06e+03     3.6e+03         0.5       0.748       0.678       0.331
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      99/99     1.86G     0.036   0.06106  0.002987       0.1        72       416: 100% 188/188 [00:18<00:00, 10.09it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 67/67 [00:09<00:00,  7.27it/s]
#                  all    1.06e+03     3.6e+03       0.488        0.75       0.675        0.33
# Optimizer stripped from runs/train/yolov5s_results2/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/yolov5s_results2/weights/best.pt, 14.8MB
# 100 epochs completed in 0.748 hours.
#
# CPU times: user 22.9 s, sys: 5.7 s, total: 28.6 s
# Wall time: 45min 34s

# %% [markdown]
# ## Inferencing with our custom Trained Model

# %%
# %cd /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5
# !python detect.py --weights /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/runs/train/yolov5s_results2/weights/best.pt --img 416 --conf 0.4 --source ../test/images
# Out:
# /content/drive/MyDrive/YOLOV5_CUSTOM/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='../test/images', update=False, view_img=False, weights=['/content/drive/MyDrive/YOLOV5_CUSTOM/yolov5/runs/train/yolov5s_results2/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16130MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7257306 parameters, 0 gradients
# image 1/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0001.jpg: 320x416 1 hats, Done. (0.013s)
# image 2/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0002.jpg: 320x416 2 vests, Done. (0.012s)
# image 3/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0003.jpg: 320x416 1 hats, Done. (0.015s)
# image 4/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0004.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 5/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0005.jpg: 320x416 3 hats, 3 gloves, Done. (0.012s)
# image 6/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0006.jpg: 320x416 2 hats, 1 vests, Done. (0.016s)
# image 7/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0007.jpg: 320x416 1 vests, Done. (0.012s)
# image 8/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0008.jpg: 320x416 5 vests, Done. (0.014s)
# image 9/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0052.jpg: 320x416 1 vests, 2 shoes, Done. (0.014s)
# image 10/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0782.jpg: 320x416 2 shoes, Done. (0.014s)
# image 11/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0783.jpg: 320x416 1 hats, 1 goggless, Done. (0.014s)
# image 12/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0784.jpg: 320x416 7 hats, 6 vests, Done. (0.014s)
# image 13/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0785.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 14/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0786.jpg: 320x416 1 hats, Done. (0.014s)
# image 15/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0787.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 16/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0788.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 17/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0789.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 18/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0898.jpg: 320x416 3 hats, 4 vests, Done. (0.011s)
# image 19/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0899.jpg: 320x416 1 vests, Done. (0.013s)
# image 20/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0900.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 21/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0901.jpg: 320x416 9 hats, 10 vests, 2 gloves, 1 shoes, Done. (0.012s)
# image 22/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0902.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 23/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0903.jpg: 320x416 4 hats, 3 vests, 1 shoes, Done. (0.012s)
# image 24/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0904.jpg: 320x416 2 hats, 2 vests, Done. (0.015s)
# image 25/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0905.jpg: 320x416 1 vests, Done. (0.013s)
# image 26/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0956.jpg: 320x416 1 shoes, Done. (0.013s)
# image 27/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0957.jpg: 320x416 Done. (0.011s)
# image 28/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0958.jpg: 320x416 1 hats, 1 shoes, Done. (0.012s)
# image 29/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0959.jpg: 320x416 3 hats, Done. (0.012s)
# image 30/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0960.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 31/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0961.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 32/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0962.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 33/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0963.jpg: 320x416 2 hats, 2 vests, Done. (0.011s)
# image 34/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0964.jpg: 320x416 5 vests, 2 gloves, Done. (0.012s)
# image 35/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0965.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 36/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0966.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 37/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0967.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 38/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0968.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 39/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0969.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 40/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0970.jpg: 320x416 2 gloves, Done. (0.012s)
# image 41/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0971.jpg: 320x416 1 hats, Done. (0.011s)
# image 42/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0972.jpg: 320x416 2 shoes, Done. (0.012s)
# image 43/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0973.jpg: 320x416 Done. (0.011s)
# image 44/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0974.jpg: 320x416 7 hats, 6 vests, Done. (0.012s)
# image 45/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0975.jpg: 320x416 1 vests, Done. (0.013s)
# image 46/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0976.jpg: 320x416 5 hats, 5 vests, 2 gloves, Done. (0.012s)
# image 47/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0977.jpg: 320x416 2 gloves, Done. (0.012s)
# image 48/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0978.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 49/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0979.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 50/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0980.jpg: 320x416 5 vests, Done. (0.012s)
# image 51/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0981.jpg: 320x416 Done. (0.012s)
# image 52/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0982.jpg: 320x416 5 hats, 5 vests, 2 gloves, Done. (0.012s)
# image 53/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0983.jpg: 320x416 1 vests, 1 gloves, Done. (0.011s)
# image 54/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0984.jpg: 320x416 5 hats, 5 vests, 2 gloves, Done. (0.016s)
# image 55/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0985.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 56/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0986.jpg: 320x416 3 hats, 3 vests, Done. (0.012s)
# image 57/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0987.jpg: 320x416 2 shoes, Done. (0.012s)
# image 58/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0988.jpg: 320x416 1 hats, Done. (0.011s)
# image 59/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0989.jpg: 320x416 1 hats, 2 shoes, Done. (0.012s)
# image 60/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0990.jpg: 320x416 5 hats, Done. (0.012s)
# image 61/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0991.jpg: 320x416 1 hats, 1 gloves, Done. (0.012s)
# image 62/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0992.jpg: 320x416 1 hats, 1 gloves, Done. (0.012s)
# image 63/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0993.jpg: 320x416 1 hats, 3 vests, 3 shoes, Done. (0.012s)
# image 64/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0994.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 65/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0995.jpg: 320x416 1 hats, 3 vests, 3 shoes, Done. (0.011s)
# image 66/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0996.jpg: 320x416 1 vests, Done. (0.012s)
# image 67/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0997.jpg: 320x416 1 vests, Done. (0.012s)
# image 68/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0998.jpg: 320x416 2 shoes, Done. (0.012s)
# image 69/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_0999.jpg: 320x416 1 hats, Done. (0.012s)
# image 70/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1000.jpg: 320x416 1 hats, 2 vests, 1 shoes, Done. (0.012s)
# image 71/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1073.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 72/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1074.jpg: 320x416 5 hats, Done. (0.014s)
# image 73/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1075.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 74/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1076.jpg: 320x416 3 hats, Done. (0.014s)
# image 75/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1077.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 76/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1078.jpg: 320x416 1 hats, Done. (0.012s)
# image 77/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1079.jpg: 320x416 Done. (0.013s)
# image 78/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1080.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 79/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1081.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.014s)
# image 80/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1123.jpg: 320x416 1 hats, 3 vests, 1 shoes, Done. (0.015s)
# image 81/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1176.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 82/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1177.jpg: 320x416 1 hats, Done. (0.012s)
# image 83/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1178.jpg: 320x416 1 shoes, Done. (0.012s)
# image 84/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1179.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 85/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1181.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 86/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1182.jpg: 320x416 2 hats, 1 goggless, Done. (0.012s)
# image 87/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1183.jpg: 320x416 1 goggless, Done. (0.012s)
# image 88/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1184.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 89/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1185.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 90/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1187.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 91/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1188.jpg: 320x416 1 goggless, Done. (0.012s)
# image 92/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1189.jpg: 320x416 1 hats, 3 vests, 3 shoes, Done. (0.012s)
# image 93/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1190.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 94/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1191.jpg: 320x416 2 shoes, Done. (0.012s)
# image 95/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1193.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 96/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1194.jpg: 320x416 1 vests, Done. (0.012s)
# image 97/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1215.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 98/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1250.jpg: 320x416 1 vests, Done. (0.013s)
# image 99/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1251.jpg: 320x416 3 hats, 2 shoes, Done. (0.012s)
# image 100/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1252.jpg: 320x416 4 hats, 3 vests, 1 shoes, Done. (0.012s)
# image 101/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1253.jpg: 320x416 2 hats, 2 vests, Done. (0.011s)
# image 102/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1254.jpg: 320x416 3 vests, Done. (0.012s)
# image 103/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1255.jpg: 320x416 1 shoes, Done. (0.012s)
# image 104/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1256.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 105/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1257.jpg: 320x416 3 hats, Done. (0.012s)
# image 106/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1258.jpg: 320x416 3 hats, Done. (0.012s)
# image 107/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1259.jpg: 320x416 1 hats, Done. (0.012s)
# image 108/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1261.jpg: 320x416 1 hats, 3 vests, 3 shoes, Done. (0.013s)
# image 109/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1262.jpg: 320x416 1 hats, 3 vests, 1 shoes, Done. (0.011s)
# image 110/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1263.jpg: 320x416 2 hats, Done. (0.012s)
# image 111/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1264.jpg: 320x416 1 goggless, Done. (0.012s)
# image 112/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1265.jpg: 320x416 1 hats, 1 vests, 1 gloves, 2 shoes, Done. (0.014s)
# image 113/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1268.jpg: 320x416 1 hats, 1 vests, 2 gloves, 2 shoes, Done. (0.013s)
# image 114/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1270.jpg: 320x416 1 hats, 8 shoes, Done. (0.014s)
# image 115/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1271.jpg: 320x416 5 vests, 3 shoes, Done. (0.023s)
# image 116/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1272.jpg: 320x416 1 hats, 1 goggless, Done. (0.015s)
# image 117/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1273.jpg: 320x416 2 hats, 1 vests, 1 goggless, Done. (0.014s)
# image 118/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1274.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 119/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1275.jpg: 320x416 1 goggless, 1 gloves, Done. (0.012s)
# image 120/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1276.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 121/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1278.jpg: 320x416 3 hats, 3 vests, 2 shoes, Done. (0.012s)
# image 122/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1279.jpg: 320x416 1 hats, 1 vests, 1 shoes, Done. (0.012s)
# image 123/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1280.jpg: 320x416 3 vests, 3 gloves, 4 shoes, Done. (0.012s)
# image 124/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1281.jpg: 320x416 2 vests, Done. (0.012s)
# image 125/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1282.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 126/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1283.jpg: 320x416 4 hats, Done. (0.012s)
# image 127/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1284.jpg: 320x416 1 vests, Done. (0.012s)
# image 128/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1285.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 129/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1286.jpg: 320x416 1 hats, 1 vests, 1 gloves, 2 shoes, Done. (0.012s)
# image 130/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1287.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 131/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1288.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 132/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1289.jpg: 320x416 1 hats, Done. (0.013s)
# image 133/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1291.jpg: 320x416 1 hats, Done. (0.012s)
# image 134/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1292.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 135/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1293.jpg: 320x416 3 hats, 3 vests, Done. (0.012s)
# image 136/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1294.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 137/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1297.jpg: 320x416 2 hats, 2 vests, 4 shoes, Done. (0.012s)
# image 138/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1298.jpg: 320x416 1 hats, 1 vests, 2 shoes, Done. (0.015s)
# image 139/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1299.jpg: 320x416 3 hats, 13 vests, Done. (0.015s)
# image 140/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1300.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 141/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1301.jpg: 320x416 1 vests, Done. (0.013s)
# image 142/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1302.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 143/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1303.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 144/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1306.jpg: 320x416 1 hats, 1 vests, 1 gloves, Done. (0.012s)
# image 145/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1307.jpg: 320x416 1 hats, Done. (0.014s)
# image 146/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1308.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 147/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1309.jpg: 320x416 2 vests, Done. (0.012s)
# image 148/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1311.jpg: 320x416 1 vests, 1 gloves, 2 shoes, Done. (0.012s)
# image 149/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1312.jpg: 320x416 1 vests, Done. (0.012s)
# image 150/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1313.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 151/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1314.jpg: 320x416 2 shoes, Done. (0.012s)
# image 152/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1315.jpg: 320x416 2 hats, 4 vests, 1 shoes, Done. (0.012s)
# image 153/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1316.jpg: 320x416 1 hats, Done. (0.012s)
# image 154/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1317.jpg: 320x416 2 gloves, Done. (0.012s)
# image 155/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1318.jpg: 320x416 2 hats, 2 vests, 4 shoes, Done. (0.012s)
# image 156/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1319.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 157/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1320.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 158/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1321.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 159/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1322.jpg: 320x416 2 hats, Done. (0.015s)
# image 160/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1323.jpg: 320x416 1 hats, 1 goggless, Done. (0.016s)
# image 161/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1324.jpg: 320x416 4 vests, 3 goggless, 1 gloves, Done. (0.017s)
# image 162/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1325.jpg: 320x416 4 hats, 1 vests, Done. (0.012s)
# image 163/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1342.jpg: 320x416 1 vests, Done. (0.012s)
# image 164/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1343.jpg: 320x416 1 hats, 3 vests, 1 shoes, Done. (0.012s)
# image 165/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1345.jpg: 320x416 1 hats, Done. (0.012s)
# image 166/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1346.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 167/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1347.jpg: 320x416 1 goggless, 2 gloves, 1 shoes, Done. (0.014s)
# image 168/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1350.jpg: 320x416 1 vests, Done. (0.013s)
# image 169/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1351.jpg: 320x416 1 shoes, Done. (0.011s)
# image 170/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1352.jpg: 320x416 1 vests, Done. (0.011s)
# image 171/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1353.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.014s)
# image 172/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1556.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 173/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1557.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 174/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1560.jpg: 320x416 4 hats, 4 vests, Done. (0.016s)
# image 175/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1561.jpg: 320x416 2 shoes, Done. (0.016s)
# image 176/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1563.jpg: 320x416 1 hats, Done. (0.012s)
# image 177/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1564.jpg: 320x416 2 shoes, Done. (0.012s)
# image 178/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1565.jpg: 320x416 1 hats, 4 vests, 2 shoes, Done. (0.011s)
# image 179/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1566.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 180/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1568.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 181/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1569.jpg: 320x416 Done. (0.011s)
# image 182/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1570.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 183/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1571.jpg: 320x416 2 hats, 1 vests, 6 shoes, Done. (0.012s)
# image 184/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1574.jpg: 320x416 1 hats, 1 goggless, 1 gloves, Done. (0.012s)
# image 185/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1575.jpg: 320x416 1 hats, 1 gloves, Done. (0.012s)
# image 186/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1578.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 187/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1579.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 188/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1580.jpg: 320x416 1 hats, 1 vests, 1 gloves, 2 shoes, Done. (0.011s)
# image 189/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1581.jpg: 320x416 3 vests, Done. (0.015s)
# image 190/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1582.jpg: 320x416 1 vests, Done. (0.013s)
# image 191/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1584.jpg: 320x416 5 hats, 5 vests, 2 gloves, Done. (0.011s)
# image 192/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1585.jpg: 320x416 1 hats, 1 vests, 1 gloves, Done. (0.012s)
# image 193/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1586.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 194/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1587.jpg: 320x416 1 hats, 2 vests, Done. (0.014s)
# image 195/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1588.jpg: 320x416 3 vests, Done. (0.017s)
# image 196/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1589.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 197/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1591.jpg: 320x416 1 hats, 4 vests, 2 shoes, Done. (0.012s)
# image 198/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1593.jpg: 320x416 1 hats, Done. (0.012s)
# image 199/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1594.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 200/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1595.jpg: 320x416 1 hats, 3 vests, 1 shoes, Done. (0.012s)
# image 201/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1598.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 202/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1600.jpg: 320x416 1 hats, 2 gloves, Done. (0.012s)
# image 203/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1602.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 204/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1603.jpg: 320x416 1 hats, Done. (0.012s)
# image 205/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1604.jpg: 320x416 3 vests, Done. (0.012s)
# image 206/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1605.jpg: 320x416 1 hats, 1 goggless, 1 gloves, Done. (0.014s)
# image 207/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1606.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 208/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1607.jpg: 320x416 2 hats, Done. (0.012s)
# image 209/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1608.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 210/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1609.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 211/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1610.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 212/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1611.jpg: 320x416 2 hats, Done. (0.012s)
# image 213/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1612.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 214/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1613.jpg: 320x416 1 hats, 2 vests, 1 shoes, Done. (0.012s)
# image 215/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1614.jpg: 320x416 4 hats, 1 vests, Done. (0.012s)
# image 216/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1615.jpg: 320x416 2 hats, 1 gloves, Done. (0.012s)
# image 217/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1617.jpg: 320x416 1 vests, Done. (0.012s)
# image 218/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1618.jpg: 320x416 1 hats, Done. (0.012s)
# image 219/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1619.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 220/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1620.jpg: 320x416 1 hats, 2 vests, Done. (0.017s)
# image 221/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1621.jpg: 320x416 2 hats, 1 gloves, Done. (0.012s)
# image 222/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1622.jpg: 320x416 1 hats, Done. (0.012s)
# image 223/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1623.jpg: 320x416 2 hats, 2 vests, 1 shoes, Done. (0.012s)
# image 224/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1624.jpg: 320x416 2 hats, 2 vests, Done. (0.016s)
# image 225/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1625.jpg: 320x416 2 hats, 2 vests, Done. (0.013s)
# image 226/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1626.jpg: 320x416 1 vests, Done. (0.012s)
# image 227/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1630.jpg: 320x416 5 shoes, Done. (0.023s)
# image 228/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1631.jpg: 320x416 6 hats, Done. (0.019s)
# image 229/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1634.jpg: 320x416 1 vests, Done. (0.012s)
# image 230/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1635.jpg: 320x416 1 hats, Done. (0.012s)
# image 231/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1636.jpg: 320x416 1 hats, Done. (0.012s)
# image 232/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1637.jpg: 320x416 2 vests, Done. (0.012s)
# image 233/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1638.jpg: 320x416 1 vests, 1 gloves, Done. (0.012s)
# image 234/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1639.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 235/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1640.jpg: 320x416 2 hats, 4 shoes, Done. (0.013s)
# image 236/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1641.jpg: 320x416 2 hats, Done. (0.012s)
# image 237/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1642.jpg: 320x416 1 hats, 2 vests, Done. (0.012s)
# image 238/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1645.jpg: 320x416 1 hats, Done. (0.011s)
# image 239/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1647.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 240/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1649.jpg: 320x416 5 vests, 1 shoes, Done. (0.012s)
# image 241/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1651.jpg: 320x416 2 hats, Done. (0.012s)
# image 242/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1652.jpg: 320x416 2 hats, 2 shoes, Done. (0.012s)
# image 243/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1653.jpg: 320x416 1 vests, Done. (0.012s)
# image 244/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1659.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 245/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1662.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 246/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1663.jpg: 320x416 2 vests, Done. (0.011s)
# image 247/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1664.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 248/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1665.jpg: 320x416 1 hats, Done. (0.011s)
# image 249/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1666.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 250/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1668.jpg: 320x416 1 hats, 1 vests, Done. (0.011s)
# image 251/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1669.jpg: 320x416 3 hats, 3 vests, Done. (0.011s)
# image 252/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1670.jpg: 320x416 2 hats, Done. (0.012s)
# image 253/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1671.jpg: 320x416 1 hats, Done. (0.012s)
# image 254/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1672.jpg: 320x416 1 hats, 2 vests, Done. (0.016s)
# image 255/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1673.jpg: 320x416 2 hats, 2 vests, Done. (0.015s)
# image 256/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1674.jpg: 320x416 4 hats, Done. (0.012s)
# image 257/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1675.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 258/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1676.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 259/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1893.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 260/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1894.jpg: 320x416 1 hats, Done. (0.011s)
# image 261/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1895.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 262/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1896.jpg: 320x416 3 hats, 3 vests, 1 shoes, Done. (0.014s)
# image 263/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1897.jpg: 320x416 1 hats, Done. (0.015s)
# image 264/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1898.jpg: 320x416 1 hats, 2 vests, 1 gloves, Done. (0.014s)
# image 265/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1899.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 266/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1900.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 shoes, Done. (0.017s)
# image 267/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1902.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 268/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1903.jpg: 320x416 1 hats, Done. (0.014s)
# image 269/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1904.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 270/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1905.jpg: 320x416 1 hats, 1 shoes, Done. (0.012s)
# image 271/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1906.jpg: 320x416 1 vests, 1 shoes, Done. (0.013s)
# image 272/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1907.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 273/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1909.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 274/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1910.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.014s)
# image 275/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1911.jpg: 320x416 1 hats, Done. (0.011s)
# image 276/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1913.jpg: 320x416 2 hats, Done. (0.012s)
# image 277/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1914.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.012s)
# image 278/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1915.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 279/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1916.jpg: 320x416 2 hats, 1 goggless, Done. (0.012s)
# image 280/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1918.jpg: 320x416 1 hats, Done. (0.012s)
# image 281/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1919.jpg: 320x416 2 hats, 2 vests, 2 gloves, Done. (0.012s)
# image 282/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1920.jpg: 320x416 1 hats, 1 goggless, Done. (0.012s)
# image 283/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1921.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 284/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1924.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 285/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1925.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 286/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1927.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 287/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1928.jpg: 320x416 1 gloves, Done. (0.012s)
# image 288/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1929.jpg: 320x416 2 hats, 2 vests, Done. (0.013s)
# image 289/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1930.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 290/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1931.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.012s)
# image 291/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1932.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 292/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1933.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 293/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1934.jpg: 320x416 2 hats, 1 goggless, 1 shoes, Done. (0.012s)
# image 294/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1935.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.012s)
# image 295/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1937.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.013s)
# image 296/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1938.jpg: 320x416 4 hats, 2 vests, Done. (0.011s)
# image 297/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1939.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.014s)
# image 298/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1940.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 299/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1941.jpg: 320x416 6 hats, 4 vests, Done. (0.012s)
# image 300/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1942.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 301/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1943.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 302/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1944.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 303/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1945.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 304/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1947.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 305/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1948.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 306/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1949.jpg: 320x416 1 vests, Done. (0.012s)
# image 307/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1950.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 308/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1951.jpg: 320x416 2 hats, 2 vests, 3 shoes, Done. (0.012s)
# image 309/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1952.jpg: 320x416 3 hats, 2 vests, 1 shoes, Done. (0.015s)
# image 310/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1953.jpg: 320x416 2 hats, 2 vests, Done. (0.015s)
# image 311/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1954.jpg: 320x416 6 hats, 1 shoes, Done. (0.016s)
# image 312/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1955.jpg: 320x416 1 hats, Done. (0.012s)
# image 313/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1956.jpg: 320x416 2 hats, 1 vests, Done. (0.014s)
# image 314/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1957.jpg: 320x416 2 hats, 3 vests, Done. (0.012s)
# image 315/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1958.jpg: 320x416 1 hats, Done. (0.012s)
# image 316/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1959.jpg: 320x416 1 hats, 1 gloves, Done. (0.012s)
# image 317/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1960.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 318/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1961.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 319/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1962.jpg: 320x416 1 hats, 3 vests, Done. (0.013s)
# image 320/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1964.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 321/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1965.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 322/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1966.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 323/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1967.jpg: 320x416 1 hats, Done. (0.013s)
# image 324/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1968.jpg: 320x416 4 hats, 2 vests, Done. (0.012s)
# image 325/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1969.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 326/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1970.jpg: 320x416 1 hats, 1 vests, 1 gloves, Done. (0.012s)
# image 327/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1971.jpg: 320x416 1 hats, Done. (0.012s)
# image 328/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1972.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 329/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1973.jpg: 320x416 2 hats, 2 vests, 1 goggless, 3 gloves, Done. (0.012s)
# image 330/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1974.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 331/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1975.jpg: 320x416 2 hats, Done. (0.014s)
# image 332/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1976.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 333/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1977.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 334/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1978.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.011s)
# image 335/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1979.jpg: 320x416 4 hats, 3 vests, Done. (0.013s)
# image 336/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1980.jpg: 320x416 3 hats, 2 vests, 1 goggless, 1 gloves, Done. (0.014s)
# image 337/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1981.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.019s)
# image 338/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1982.jpg: 320x416 2 vests, Done. (0.013s)
# image 339/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1983.jpg: 320x416 1 hats, Done. (0.012s)
# image 340/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1984.jpg: 320x416 2 gloves, Done. (0.015s)
# image 341/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1985.jpg: 320x416 1 hats, 1 vests, Done. (0.013s)
# image 342/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1986.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 343/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1987.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 344/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1988.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 345/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1990.jpg: 320x416 1 hats, 1 vests, 1 gloves, Done. (0.012s)
# image 346/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1991.jpg: 320x416 1 hats, 1 vests, 1 gloves, Done. (0.012s)
# image 347/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1992.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 348/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1993.jpg: 320x416 6 hats, 1 vests, Done. (0.012s)
# image 349/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1994.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 350/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1995.jpg: 320x416 1 hats, 2 vests, 1 shoes, Done. (0.012s)
# image 351/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1996.jpg: 320x416 2 hats, 2 vests, 1 goggless, Done. (0.013s)
# image 352/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1997.jpg: 320x416 1 hats, Done. (0.012s)
# image 353/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1998.jpg: 320x416 1 hats, 1 shoes, Done. (0.012s)
# image 354/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_1999.jpg: 320x416 1 hats, 1 vests, 1 goggless, 2 gloves, Done. (0.012s)
# image 355/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2000.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 356/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2002.jpg: 320x416 1 hats, 1 vests, Done. (0.011s)
# image 357/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2003.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 358/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2004.jpg: 320x416 4 hats, 2 vests, Done. (0.012s)
# image 359/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2005.jpg: 320x416 2 shoes, Done. (0.020s)
# image 360/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2006.jpg: 320x416 1 hats, Done. (0.013s)
# image 361/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2007.jpg: 320x416 2 hats, Done. (0.012s)
# image 362/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2008.jpg: 320x416 1 hats, 1 vests, 1 goggless, 1 gloves, Done. (0.012s)
# image 363/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2009.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 364/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2010.jpg: 320x416 2 gloves, Done. (0.011s)
# image 365/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2011.jpg: 320x416 1 vests, 1 shoes, Done. (0.012s)
# image 366/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2012.jpg: 320x416 1 hats, 2 gloves, Done. (0.012s)
# image 367/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2013.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 368/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2014.jpg: 320x416 Done. (0.011s)
# image 369/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2015.jpg: 320x416 2 gloves, Done. (0.012s)
# image 370/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2016.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 371/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2017.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 372/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2018.jpg: 320x416 1 vests, Done. (0.012s)
# image 373/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2019.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 374/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_2020.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# ...
# image 934/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3877.jpg: 320x416 2 hats, 1 vests, Done. (0.015s)
# image 935/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3878.jpg: 320x416 5 gloves, Done. (0.012s)
# image 936/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3880.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 937/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3881.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 938/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3882.jpg: 320x416 3 hats, 3 vests, Done. (0.012s)
# image 939/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3884.jpg: 320x416 2 hats, 2 vests, 1 gloves, Done. (0.012s)
# image 940/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3885.jpg: 320x416 1 hats, 1 vests, Done. (0.015s)
# image 941/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3891.jpg: 320x416 4 hats, Done. (0.015s)
# image 942/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3897.jpg: 320x416 2 hats, 1 goggless, 1 gloves, Done. (0.012s)
# image 943/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3898.jpg: 320x416 3 hats, 3 vests, Done. (0.012s)
# image 944/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3903.jpg: 320x416 2 vests, Done. (0.014s)
# image 945/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3905.jpg: 320x416 2 vests, Done. (0.014s)
# image 946/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3907.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 947/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3909.jpg: 320x416 2 hats, 1 vests, Done. (0.021s)
# image 948/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3910.jpg: 320x416 1 hats, Done. (0.015s)
# image 949/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3911.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 950/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3912.jpg: 320x416 2 hats, Done. (0.012s)
# image 951/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3913.jpg: 320x416 2 vests, Done. (0.012s)
# image 952/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3918.jpg: 320x416 2 vests, 3 shoes, Done. (0.012s)
# image 953/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3919.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 954/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3920.jpg: 320x416 2 hats, 2 vests, Done. (0.014s)
# image 955/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3921.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 956/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3932.jpg: 320x416 2 hats, 1 gloves, Done. (0.015s)
# image 957/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3933.jpg: 320x416 1 hats, 1 vests, 3 shoes, Done. (0.016s)
# image 958/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3943.jpg: 320x416 2 hats, 1 goggless, Done. (0.016s)
# image 959/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3944.jpg: 320x416 2 vests, Done. (0.012s)
# image 960/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3945.jpg: 320x416 2 vests, Done. (0.012s)
# image 961/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3948.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 962/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3949.jpg: 320x416 1 hats, 2 vests, 3 shoes, Done. (0.012s)
# image 963/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3953.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 964/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3954.jpg: 320x416 3 vests, 5 shoes, Done. (0.012s)
# image 965/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3955.jpg: 320x416 1 hats, 2 vests, Done. (0.012s)
# image 966/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3957.jpg: 320x416 6 vests, 5 shoes, Done. (0.013s)
# image 967/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3958.jpg: 320x416 2 hats, 2 vests, 3 shoes, Done. (0.012s)
# image 968/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3959.jpg: 320x416 3 vests, Done. (0.012s)
# image 969/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3960.jpg: 320x416 3 vests, 1 shoes, Done. (0.012s)
# image 970/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3962.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 971/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3963.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 972/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3964.jpg: 320x416 1 vests, Done. (0.012s)
# image 973/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3965.jpg: 320x416 1 hats, 1 vests, 2 shoes, Done. (0.012s)
# image 974/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3966.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.013s)
# image 975/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3967.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 976/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3968.jpg: 320x416 3 hats, 1 vests, 1 gloves, 1 shoes, Done. (0.012s)
# image 977/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3970.jpg: 320x416 2 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 978/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3971.jpg: 320x416 1 hats, 1 vests, Done. (0.011s)
# image 979/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3972.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 980/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3973.jpg: 320x416 3 hats, 1 vests, Done. (0.012s)
# image 981/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3974.jpg: 320x416 2 hats, 1 goggless, Done. (0.012s)
# image 982/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3975.jpg: 320x416 2 hats, 1 vests, 1 goggless, 2 gloves, Done. (0.013s)
# image 983/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3976.jpg: 320x416 1 hats, Done. (0.012s)
# image 984/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3977.jpg: 320x416 Done. (0.011s)
# image 985/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3978.jpg: 320x416 1 hats, 1 goggless, 1 shoes, Done. (0.011s)
# image 986/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3979.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 987/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3980.jpg: 320x416 2 shoes, Done. (0.015s)
# image 988/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3981.jpg: 320x416 1 hats, Done. (0.014s)
# image 989/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3982.jpg: 320x416 2 hats, 1 goggless, Done. (0.014s)
# image 990/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3983.jpg: 320x416 3 hats, 2 vests, 2 goggless, 2 gloves, Done. (0.014s)
# image 991/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3984.jpg: 320x416 2 hats, 2 vests, 1 gloves, Done. (0.014s)
# image 992/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3985.jpg: 320x416 2 hats, 2 goggless, Done. (0.012s)
# image 993/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3986.jpg: 320x416 3 hats, 2 vests, 4 shoes, Done. (0.012s)
# image 994/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3987.jpg: 320x416 1 hats, Done. (0.012s)
# image 995/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3988.jpg: 320x416 1 hats, Done. (0.012s)
# image 996/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3989.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 997/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3990.jpg: 320x416 1 hats, Done. (0.013s)
# image 998/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3991.jpg: 320x416 2 hats, 1 vests, 1 shoes, Done. (0.012s)
# image 999/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3992.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 1000/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3993.jpg: 320x416 1 hats, Done. (0.012s)
# image 1001/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3994.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 1002/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3995.jpg: 320x416 2 shoes, Done. (0.015s)
# image 1003/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3996.jpg: 320x416 1 hats, 1 vests, 1 goggless, Done. (0.012s)
# image 1004/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3997.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 1005/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3998.jpg: 320x416 1 hats, Done. (0.013s)
# image 1006/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_3999.jpg: 320x416 2 hats, 1 vests, Done. (0.012s)
# image 1007/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4000.jpg: 320x416 2 hats, 2 vests, Done. (0.012s)
# image 1008/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4651.jpg: 320x416 4 vests, Done. (0.012s)
# image 1009/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4652.jpg: 320x416 5 vests, Done. (0.012s)
# image 1010/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4653.jpg: 320x416 4 vests, Done. (0.012s)
# image 1011/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4654.jpg: 320x416 4 vests, Done. (0.012s)
# image 1012/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4655.jpg: 320x416 3 vests, Done. (0.012s)
# image 1013/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4656.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 1014/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4657.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 1015/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4658.jpg: 320x416 1 hats, 1 vests, Done. (0.012s)
# image 1016/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4659.jpg: 320x416 2 vests, Done. (0.013s)
# image 1017/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4756.jpg: 320x416 7 vests, 1 shoes, Done. (0.013s)
# image 1018/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4796.jpg: 320x416 2 vests, Done. (0.015s)
# image 1019/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4797.jpg: 320x416 2 vests, 1 shoes, Done. (0.012s)
# image 1020/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4798.jpg: 320x416 2 vests, Done. (0.012s)
# image 1021/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4799.jpg: 320x416 5 vests, Done. (0.012s)
# image 1022/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4800.jpg: 320x416 7 vests, 12 shoes, Done. (0.012s)
# image 1023/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4801.jpg: 320x416 6 vests, 12 shoes, Done. (0.012s)
# image 1024/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4802.jpg: 320x416 6 vests, 14 shoes, Done. (0.012s)
# image 1025/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4803.jpg: 320x416 6 vests, 9 shoes, Done. (0.013s)
# image 1026/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4828.jpg: 320x416 1 vests, Done. (0.012s)
# image 1027/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4829.jpg: 320x416 1 vests, Done. (0.012s)
# image 1028/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4830.jpg: 320x416 1 vests, Done. (0.014s)
# image 1029/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4831.jpg: 320x416 1 vests, Done. (0.012s)
# image 1030/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4832.jpg: 320x416 1 vests, Done. (0.012s)
# image 1031/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4833.jpg: 320x416 1 vests, Done. (0.012s)
# image 1032/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4834.jpg: 320x416 1 vests, Done. (0.011s)
# image 1033/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4835.jpg: 320x416 1 vests, 1 shoes, Done. (0.012s)
# image 1034/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4868.jpg: 320x416 2 vests, Done. (0.012s)
# image 1035/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4910.jpg: 320x416 2 vests, Done. (0.012s)
# image 1036/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4911.jpg: 320x416 2 vests, Done. (0.012s)
# image 1037/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4912.jpg: 320x416 1 vests, Done. (0.012s)
# image 1038/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4913.jpg: 320x416 2 vests, Done. (0.012s)
# image 1039/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4914.jpg: 320x416 1 vests, Done. (0.012s)
# image 1040/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4915.jpg: 320x416 2 vests, Done. (0.012s)
# image 1041/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4916.jpg: 320x416 1 hats, 1 vests, Done. (0.014s)
# image 1042/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4917.jpg: 320x416 1 vests, Done. (0.013s)
# image 1043/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4967.jpg: 320x416 1 vests, Done. (0.013s)
# image 1044/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4968.jpg: 320x416 1 vests, Done. (0.012s)
# image 1045/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4969.jpg: 320x416 2 vests, Done. (0.012s)
# image 1046/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4970.jpg: 320x416 3 vests, 1 gloves, Done. (0.015s)
# image 1047/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4971.jpg: 320x416 1 vests, Done. (0.013s)
# image 1048/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4972.jpg: 320x416 1 vests, 2 gloves, Done. (0.012s)
# image 1049/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4973.jpg: 320x416 1 vests, Done. (0.012s)
# image 1050/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4974.jpg: 320x416 2 vests, 1 gloves, Done. (0.016s)
# image 1051/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_4975.jpg: 320x416 1 vests, 1 gloves, Done. (0.012s)
# image 1052/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5026.jpg: 320x416 6 vests, 8 shoes, Done. (0.012s)
# image 1053/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5027.jpg: 320x416 2 vests, Done. (0.012s)
# image 1054/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5028.jpg: 320x416 3 vests, 1 shoes, Done. (0.012s)
# image 1055/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5029.jpg: 320x416 1 vests, Done. (0.012s)
# image 1056/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5030.jpg: 320x416 1 vests, Done. (0.012s)
# image 1057/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5031.jpg: 320x416 1 vests, 1 shoes, Done. (0.013s)
# image 1058/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5032.jpg: 320x416 7 vests, 1 shoes, Done. (0.012s)
# image 1059/1059 /content/drive/MyDrive/YOLOV5_CUSTOM/test/images/wh_dresscode_5033.jpg: 320x416 3 vests, Done. (0.011s)
# Results saved to runs/detect/exp
# Done. (46.800s)
